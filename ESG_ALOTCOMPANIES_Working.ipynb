# %%
import refinitiv.data as rd
import numpy as np
import pandas as pd
import matplotlib as plt
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
rd.open_session()
# Out:
# <refinitiv.data.session.Definition object at 0x7fd6be5e81c0 {name='codebook'}>

# %%
# which index is used as a basis of comparison
index = '.SPX'
# what is the time range for the backtesting 
start_year = 2014
end_year = 2023
# what is the company's  minimum ESG Score (0-100) for the high ESG subset
ESG_score_threshold = 70

# %%
sp = rd.get_data(index, fields=['TR.PRICECLOSE.date', 'TR.PRICECLOSE'], parameters={'SDate': '{}-01-01'.format(start_year), 'EDate': '{}-01-01'.format(end_year), 'Frq':'CQ'})

# %%
sp['Rebased'] = sp['Price Close'] * 100 / sp['Price Close'][0]
sp.head()
# Out:
#   Instrument       Date  Price Close     Rebased
# 0       .SPX 2014-03-31      1872.34       100.0
# 1       .SPX 2014-06-30      1960.23  104.694126
# 2       .SPX 2014-09-30      1972.29   105.33824
# 3       .SPX 2014-12-31       2058.9  109.964002
# 4       .SPX 2015-03-31      2067.89   110.44415

# %%
sp.to_csv('SnP500.csv', index=False)

# %% [markdown]
# ## Getting Data from Companies
#
# first get the companies that has esg coverage, then we'll get their price close.

# %%
# Europe, Africa, and Oceania
df_eur_Af_oce = rd.get_data(["SCREEN(U(IN(Equity(active,public,primary))/*UNV:Public*/), TR.HasESGCoverage==true, IN(TR.HeadquartersRegion,""Europe"",""Africa"",""Oceania""), CURN=USD)"],["TR.CommonName;TR.HasESGCoverage;TR.HeadquartersRegion"])


# Asia
df_asia = rd.get_data(["SCREEN(U(IN(Equity(active,public,primary))/*UNV:Public*/), TR.HasESGCoverage==true, IN(TR.HeadquartersRegion,""Asia""), CURN=USD)"],["TR.CommonName;TR.HasESGCoverage;TR.HeadquartersRegion"])


# Americas
df_am = rd.get_data(["SCREEN(U(IN(Equity(active,public,primary))/*UNV:Public*/), TR.HasESGCoverage==true,  IN(TR.HeadquartersRegion,""Americas""), CURN=USD)"],["TR.CommonName;TR.HasESGCoverage;TR.HeadquartersRegion"])

# concat all
esg_All = pd.concat([df_eur_Af_oce, df_asia, df_am], ignore_index=True)
esg_All
# Out:
#       Instrument                Company Common Name  ESG Coverage Flag  \
# 0        MBWS.PA  Marie Brizard Wine and Spirits SA               True
# 1         AFEJ.J                           AECI Ltd               True
# 2         AELJ.J                         Altron Ltd               True
# 3          AAL.L                 Anglo American PLC               True
# 4         AVIJ.J                            Avi Ltd               True
# ...          ...                                ...                ...
# 14534    BTSG.OQ   Brightspring Health Services Inc               True
# 14535     IBTA.N                         Ibotta Inc               True
# 14536     RBRK.N                         Rubrik Inc               True
# 14537    INBX.OQ            Inhibrx Biosciences Inc               True
# 14538    WWOK.PK                         WeWork Inc               True
#
#       Region of Headquarters
# 0                     Europe
# 1                     Africa
# 2                     Africa
# 3                     Europe
# 4                     Africa
# ...                      ...
# 14534               Americas
# 14535               Americas
# 14536               Americas
# 14537               Americas
# 14538               Americas
#
# [14539 rows x 4 columns]

# %%
esg_All.to_csv("iNS_esgcov_regionHQ.csv")

# %%
def chunks(l, n):
    for i in range(0,len(l),n):
        yield l[i:i+n]
        
def data_to_dict(df3, my_dict, empty_rics):
    rics = []
    [rics.append(ric[0]) for ric in df3.columns]
    rics = list(set(rics))
    for ric in rics:
        df3_ric = df3[ric].dropna(subset = ['ESG Combined Score'])
        if len(df3_ric) > 0:
            my_dict[ric] = {'date_min':'2014-01-01', 'date_max':df3_ric['ESG Period Last Update Date'][-1]}
        else:
            empty_rics.append(ric)
    return my_dict, empty_rics


ric_chunks = list(chunks(list(esg_All['Instrument'].values),1000))
i = 0
my_dict ={}
empty_rics = []
for chunk in ric_chunks:
    i+=1
    print(len(ric_chunks)-i)
    max_retry = 0
    while max_retry<3:
        try:
            df3 = rd.get_history(chunk,['TR.TRESGCScore(SDate=0,EDate=-19,Period=FY0,Frq=FY)',
                                        'TR.ESGPeriodLastUpdateDate(SDate=0,EDate=-19,Period=FY0,Frq=FY)'])
            if len(df3) >0:
                my_dict, empty_rics = data_to_dict(df3, my_dict, empty_rics)
        except Exception as e:
            print(e)
            max_retry+=1
            continue
        
        break
# Out:
# 14
# 13
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_440/2332649067.py in <module>
#      26     while max_retry<3:
#      27         try:
# ---> 28             df3 = rd.get_history(chunk,['TR.TRESGCScore(SDate=0,EDate=-19,Period=FY0,Frq=FY)',
#      29                                         'TR.ESGPeriodLastUpdateDate(SDate=0,EDate=-19,Period=FY0,Frq=FY)'])
#      30             if len(df3) >0:
#
# /opt/conda/lib/python3.8/site-packages/refinitiv/data/_access_layer/get_history_func.py in get_history(universe, fields, interval, start, end, adjustments, count, use_field_names_in_headers, parameters)
#     158         adc_params = get_adc_params(start, end, interval)
#     159         adc_params.update(parameters or {})
# --> 160         adc_raw, adc_df, adc_exception_msg = get_adc_data(
#     161             universe=universe.adc,
#     162             fields=fields.adc,
#
# /opt/conda/lib/python3.8/site-packages/refinitiv/data/_access_layer/_data_provider.py in get_adc_data(universe, fields, parameters, use_field_names_in_headers, logger, use_field_names_in_headers_passed)
#     126         response = definition.get_data()
#     127         raw = response.data.raw
# --> 128         df = response.data.df
#     129         DEBUG and logger.debug(f"ADC --->\n{response.data.df.to_string()}\n")
#     130     except ScopeError as scope_error:
#
# /opt/conda/lib/python3.8/site-packages/refinitiv/data/content/_content_data.py in df(self)
#      16     def df(self):
#      17         if self._dataframe is None:
# ---> 18             self._dataframe = self._dfbuilder(self.raw, **self._kwargs)
#      19
#      20         return self._dataframe
#
# /opt/conda/lib/python3.8/site-packages/refinitiv/data/content/_df_builder.py in build_date_as_index(self, content_data, use_field_names_in_headers, use_multiindex, sort_ascending, **kwargs)
#     410         index = pd.Index(data=index, name=date_column_name)
#     411         df = pd.DataFrame(data=data, columns=columns, index=index)
# --> 412         df = convert_dtypes(df)
#     413         df.sort_index(ascending=sort_ascending, inplace=True)
#     414         return df
#
# /opt/conda/lib/python3.8/site-packages/refinitiv/data/_tools/_dataframe.py in convert_dtypes(df)
#     199         set_df_column_value(df, index, result)
#     200
# --> 201     df.fillna(pd.NA, inplace=True)
#     202     return df
#     203
#
# /opt/conda/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    5174         downcast=None,
#    5175     ) -> DataFrame | None:
# -> 5176         return super().fillna(
#    5177             value=value,
#    5178             method=method,
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    6380
#    6381             elif not is_list_like(value):
# -> 6382                 new_data = self._mgr.fillna(
#    6383                     value=value, limit=limit, inplace=inplace, downcast=downcast
#    6384                 )
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/internals/managers.py in fillna(self, value, limit, inplace, downcast)
#     408
#     409     def fillna(self: T, value, limit, inplace: bool, downcast) -> T:
# --> 410         return self.apply(
#     411             "fillna", value=value, limit=limit, inplace=inplace, downcast=downcast
#     412         )
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/internals/blocks.py in fillna(self, value, limit, inplace, downcast)
#    1772         values = self.values
#    1773         values = values if inplace else values.copy()
# -> 1774         new_values = values.fillna(value=value, limit=limit)
#    1775         return [self.make_block_same_class(values=new_values)]
#    1776
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/_mixins.py in fillna(self, value, method, limit)
#     240                 # fill with value
#     241                 new_values = self.copy()
# --> 242                 new_values[mask] = value
#     243         else:
#     244             # We validate the fill_value even if there is nothing to fill
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/datetimelike.py in __setitem__(self, key, value)
#     371             return
#     372
# --> 373         super().__setitem__(key, value)
#     374         self._maybe_clear_freq()
#     375
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/_mixins.py in __setitem__(self, key, value)
#     181         key = check_array_indexer(self, key)
#     182         value = self._validate_setitem_value(value)
# --> 183         self._ndarray[key] = value
#     184
#     185     def _validate_setitem_value(self, value):
#
# KeyboardInterrupt:

# %%
len(esg_All)
# Out:
# 14539

# %%
pd.DataFrame(my_dict)
# Out:
#             KSBG.DE     SAN.NZ     HAYS.L     OMNJ.J    RCSM.MI   TUI1n.DE  \
# date_min 2014-01-01 2014-01-01 2014-01-01 2014-01-01 2014-01-01 2014-01-01
# date_max 2024-11-29 2024-11-22 2024-11-22 2024-11-22 2024-11-22 2024-11-22
#
#             CARRC.L     NICL.L    HEIN.AS     TSGJ.J  ...      MTO.L  \
# date_min 2014-01-01 2014-01-01 2014-01-01 2014-01-01  ... 2014-01-01
# date_max 2024-11-22 2024-11-22 2024-11-14 2024-11-22  ... 2024-11-22
#
#              ELD.AX    ACCP.PA  PSHG_p.DE    SVEG.OL    AEGN.AS    VOSG.DE  \
# date_min 2014-01-01 2014-01-01 2014-01-01 2014-01-01 2014-01-01 2014-01-01
# date_max 2024-11-22 2024-11-22 2024-11-29 2024-11-22 2024-08-23 2024-11-14
#
#              AZK.MC   RBREW.CO     MARS.L
# date_min 2014-01-01 2014-01-01 2014-01-01
# date_max 2024-11-22 2024-11-22 2024-11-22
#
# [2 rows x 918 columns]

# %% [markdown]
# ## Get ESG Scores

# %%
esg_Scores = pd.DataFrame()
i = 0
for chunk in ric_chunks:
    i+=1
    print(len(ric_chunks)-i)
    max_retry = 0
    while max_retry<3:
        try:
            df3x = rd.get_history(chunk,['TR.TRBCEconomicSector',
                                         'TR.TRESGScore(Period=FY0)',
                                         'TR.TRESGCScore(Period=FY0)',
                                         'TR.TRESGResourceUseScore(Period=FY0)',
                                         'TR.TRESGEmissionsScore(Period=FY0)',
                                         'TR.TRESGInnovationScore(Period=FY0)',
                                         'TR.TRESGWorkforceScore(Period=FY0)',
                                         'TR.TRESGHumanRightsScore(Period=FY0)',
                                         'TR.TRESGCommunityScore(Period=FY0)',
                                         'TR.TRESGProductResponsibilityScore(Period=FY0)',
                                         'TR.TRESGCControversiesScore(Period=FY0)'])
            if len(df3x):
                esg_Scores = pd.concat([esg_Scores,df3x])
            else:
                esg_Scores = df3x
        except Exception as e:
            print(e)
            continue
        break
# Out:
# 14
# 13
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_440/81657826.py in <module>
#       7     while max_retry<3:
#       8         try:
# ----> 9             df3x = rd.get_history(chunk,['TR.TRBCEconomicSector',
#      10                                          'TR.TRESGScore(Period=FY0)',
#      11                                          'TR.TRESGCScore(Period=FY0)',
#
# /opt/conda/lib/python3.8/site-packages/refinitiv/data/_access_layer/get_history_func.py in get_history(universe, fields, interval, start, end, adjustments, count, use_field_names_in_headers, parameters)
#     214
#     215     history_provider = get_history_df_builder(data_grid_type)
# --> 216     return history_provider.build_df_date_as_index(adc, hp, cust_inst, universe.hp, interval)
#     217
#     218
#
# /opt/conda/lib/python3.8/site-packages/refinitiv/data/_access_layer/_history_df_builder.py in build_df_date_as_index(self, adc, hp, cust_inst, universe, interval)
#      51                         data.append(datum)
#      52
# ---> 53                 df = adc.dfbuilder.build_date_as_index(
#      54                     {"data": data, "headers": headers},
#      55                     adc.use_field_names_in_headers,
#
# /opt/conda/lib/python3.8/site-packages/refinitiv/data/content/_df_builder.py in build_date_as_index(self, content_data, use_field_names_in_headers, use_multiindex, sort_ascending, **kwargs)
#     410         index = pd.Index(data=index, name=date_column_name)
#     411         df = pd.DataFrame(data=data, columns=columns, index=index)
# --> 412         df = convert_dtypes(df)
#     413         df.sort_index(ascending=sort_ascending, inplace=True)
#     414         return df
#
# /opt/conda/lib/python3.8/site-packages/refinitiv/data/_tools/_dataframe.py in convert_dtypes(df)
#     197
#     198         result = series.astype(inferred_dtype)
# --> 199         set_df_column_value(df, index, result)
#     200
#     201     df.fillna(pd.NA, inplace=True)
#
# /opt/conda/lib/python3.8/site-packages/refinitiv/data/_tools/_dataframe.py in set_df_column_value(df, loc, value)
#      45         df.isetitem(loc, value)
#      46     else:
# ---> 47         df.iloc[:, loc] = value
#      48
#      49     return df
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     721
#     722         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 723         iloc._setitem_with_indexer(indexer, value, self.name)
#     724
#     725     def _validate_key(self, key, axis: int):
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1728         if take_split_path:
#    1729             # We have to operate column-wise
# -> 1730             self._setitem_with_indexer_split_path(indexer, value, name)
#    1731         else:
#    1732             self._setitem_single_block(indexer, value, name)
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py in _setitem_with_indexer_split_path(self, indexer, value, name)
#    1771             elif len(ilocs) == 1 and lplane_indexer == len(value) and not is_scalar(pi):
#    1772                 # We are setting multiple rows in a single column.
# -> 1773                 self._setitem_single_column(ilocs[0], value, pi)
#    1774
#    1775             elif len(ilocs) == 1 and 0 != lplane_indexer != len(value):
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py in _setitem_single_column(self, loc, value, plane_indexer)
#    1922
#    1923         # reset the sliced object if unique
# -> 1924         self.obj._iset_item(loc, ser)
#    1925
#    1926     def _setitem_single_block(self, indexer, value, name: str):
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py in _iset_item(self, loc, value)
#    3764     def _iset_item(self, loc: int, value) -> None:
#    3765         arraylike = self._sanitize_column(value)
# -> 3766         self._iset_item_mgr(loc, arraylike)
#    3767
#    3768         # check if we are modifying a copy
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py in _iset_item_mgr(self, loc, value)
#    3744     def _iset_item_mgr(self, loc: int | slice | np.ndarray, value) -> None:
#    3745         # when called from _set_item_mgr loc can be anything returned from get_loc
# -> 3746         self._mgr.iset(loc, value)
#    3747         self._clear_item_cache()
#    3748
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/internals/managers.py in iset(self, loc, value)
#    1097             new_blknos[~is_deleted] = np.arange(self.nblocks - len(removed_blknos))
#    1098             self._blknos = new_blknos[self._blknos]
# -> 1099             self.blocks = tuple(
#    1100                 blk for i, blk in enumerate(self.blocks) if i not in set(removed_blknos)
#    1101             )
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/internals/managers.py in <genexpr>(.0)
#    1098             self._blknos = new_blknos[self._blknos]
#    1099             self.blocks = tuple(
# -> 1100                 blk for i, blk in enumerate(self.blocks) if i not in set(removed_blknos)
#    1101             )
#    1102
#
# KeyboardInterrupt:

# %%
esg_Scores
# Out:
#                              MBWS.PA                                \
#            TRBC Economic Sector Name  ESG Score ESG Combined Score
# Date
# 2008-09-30                      <NA>       <NA>               <NA>
# 2019-12-31                      <NA>       <NA>               <NA>
# 2020-11-30                      <NA>       <NA>               <NA>
# 2020-12-31                      <NA>       <NA>               <NA>
# 2021-03-31                      <NA>       <NA>               <NA>
# 2021-12-31                      <NA>       <NA>               <NA>
# 2022-01-29                      <NA>       <NA>               <NA>
# 2022-01-31                      <NA>       <NA>               <NA>
# 2022-03-31                      <NA>       <NA>               <NA>
# 2022-05-31                      <NA>       <NA>               <NA>
# 2022-06-30                      <NA>       <NA>               <NA>
# 2022-08-31                      <NA>       <NA>               <NA>
# 2022-09-03                      <NA>       <NA>               <NA>
# 2022-09-30                      <NA>       <NA>               <NA>
# 2022-10-01                      <NA>       <NA>               <NA>
# 2022-10-31                      <NA>       <NA>               <NA>
# 2022-11-30                      <NA>       <NA>               <NA>
# 2022-12-31                      <NA>       <NA>               <NA>
# 2023-01-01                      <NA>       <NA>               <NA>
# 2023-01-28                      <NA>       <NA>               <NA>
# 2023-01-29                      <NA>       <NA>               <NA>
# 2023-01-31                      <NA>       <NA>               <NA>
# 2023-02-25                      <NA>       <NA>               <NA>
# 2023-02-26                      <NA>       <NA>               <NA>
# 2023-02-28                      <NA>       <NA>               <NA>
# 2023-03-02                      <NA>       <NA>               <NA>
# 2023-03-04                      <NA>       <NA>               <NA>
# 2023-03-25                      <NA>       <NA>               <NA>
# 2023-03-31                      <NA>       <NA>               <NA>
# 2023-04-01                      <NA>       <NA>               <NA>
# 2023-04-02                      <NA>       <NA>               <NA>
# 2023-04-03                      <NA>       <NA>               <NA>
# 2023-04-28                      <NA>       <NA>               <NA>
# 2023-04-30                      <NA>       <NA>               <NA>
# 2023-05-31                      <NA>       <NA>               <NA>
# 2023-06-25                      <NA>       <NA>               <NA>
# 2023-06-30                      <NA>       <NA>               <NA>
# 2023-07-02                      <NA>       <NA>               <NA>
# 2023-07-29                      <NA>       <NA>               <NA>
# 2023-07-31                      <NA>       <NA>               <NA>
# 2023-08-01                      <NA>       <NA>               <NA>
# 2023-08-31                      <NA>       <NA>               <NA>
# 2023-09-30                      <NA>       <NA>               <NA>
# 2023-10-31                      <NA>       <NA>               <NA>
# 2023-11-30                      <NA>       <NA>               <NA>
# 2023-12-30                      <NA>       <NA>               <NA>
# 2023-12-31                            44.550386          44.550386
# 2024-01-31                      <NA>       <NA>               <NA>
# 2024-02-29                      <NA>       <NA>               <NA>
# 2024-03-30                      <NA>       <NA>               <NA>
# 2024-03-31                      <NA>       <NA>               <NA>
# 2024-04-01                      <NA>       <NA>               <NA>
# 2024-04-30                      <NA>       <NA>               <NA>
# 2024-05-31                      <NA>       <NA>               <NA>
# 2024-06-30                      <NA>       <NA>               <NA>
#
#                                                                               \
#            Resource Use Score Emissions Score Environmental Innovation Score
# Date
# 2008-09-30               <NA>            <NA>                           <NA>
# 2019-12-31               <NA>            <NA>                           <NA>
# 2020-11-30               <NA>            <NA>                           <NA>
# 2020-12-31               <NA>            <NA>                           <NA>
# 2021-03-31               <NA>            <NA>                           <NA>
# 2021-12-31               <NA>            <NA>                           <NA>
# 2022-01-29               <NA>            <NA>                           <NA>
# 2022-01-31               <NA>            <NA>                           <NA>
# 2022-03-31               <NA>            <NA>                           <NA>
# 2022-05-31               <NA>            <NA>                           <NA>
# 2022-06-30               <NA>            <NA>                           <NA>
# 2022-08-31               <NA>            <NA>                           <NA>
# 2022-09-03               <NA>            <NA>                           <NA>
# 2022-09-30               <NA>            <NA>                           <NA>
# 2022-10-01               <NA>            <NA>                           <NA>
# 2022-10-31               <NA>            <NA>                           <NA>
# 2022-11-30               <NA>            <NA>                           <NA>
# 2022-12-31               <NA>            <NA>                           <NA>
# 2023-01-01               <NA>            <NA>                           <NA>
# 2023-01-28               <NA>            <NA>                           <NA>
# 2023-01-29               <NA>            <NA>                           <NA>
# 2023-01-31               <NA>            <NA>                           <NA>
# 2023-02-25               <NA>            <NA>                           <NA>
# 2023-02-26               <NA>            <NA>                           <NA>
# 2023-02-28               <NA>            <NA>                           <NA>
# 2023-03-02               <NA>            <NA>                           <NA>
# 2023-03-04               <NA>            <NA>                           <NA>
# 2023-03-25               <NA>            <NA>                           <NA>
# 2023-03-31               <NA>            <NA>                           <NA>
# 2023-04-01               <NA>            <NA>                           <NA>
# 2023-04-02               <NA>            <NA>                           <NA>
# 2023-04-03               <NA>            <NA>                           <NA>
# 2023-04-28               <NA>            <NA>                           <NA>
# 2023-04-30               <NA>            <NA>                           <NA>
# 2023-05-31               <NA>            <NA>                           <NA>
# 2023-06-25               <NA>            <NA>                           <NA>
# 2023-06-30               <NA>            <NA>                           <NA>
# 2023-07-02               <NA>            <NA>                           <NA>
# 2023-07-29               <NA>            <NA>                           <NA>
# 2023-07-31               <NA>            <NA>                           <NA>
# 2023-08-01               <NA>            <NA>                           <NA>
# 2023-08-31               <NA>            <NA>                           <NA>
# 2023-09-30               <NA>            <NA>                           <NA>
# 2023-10-31               <NA>            <NA>                           <NA>
# 2023-11-30               <NA>            <NA>                           <NA>
# 2023-12-30               <NA>            <NA>                           <NA>
# 2023-12-31          62.272727       39.732143                      53.174603
# 2024-01-31               <NA>            <NA>                           <NA>
# 2024-02-29               <NA>            <NA>                           <NA>
# 2024-03-30               <NA>            <NA>                           <NA>
# 2024-03-31               <NA>            <NA>                           <NA>
# 2024-04-01               <NA>            <NA>                           <NA>
# 2024-04-30               <NA>            <NA>                           <NA>
# 2024-05-31               <NA>            <NA>                           <NA>
# 2024-06-30               <NA>            <NA>                           <NA>
#
#                                                                \
#            Workforce Score Human Rights Score Community Score
# Date
# 2008-09-30            <NA>               <NA>            <NA>
# 2019-12-31            <NA>               <NA>            <NA>
# 2020-11-30            <NA>               <NA>            <NA>
# 2020-12-31            <NA>               <NA>            <NA>
# 2021-03-31            <NA>               <NA>            <NA>
# 2021-12-31            <NA>               <NA>            <NA>
# 2022-01-29            <NA>               <NA>            <NA>
# 2022-01-31            <NA>               <NA>            <NA>
# 2022-03-31            <NA>               <NA>            <NA>
# 2022-05-31            <NA>               <NA>            <NA>
# 2022-06-30            <NA>               <NA>            <NA>
# 2022-08-31            <NA>               <NA>            <NA>
# 2022-09-03            <NA>               <NA>            <NA>
# 2022-09-30            <NA>               <NA>            <NA>
# 2022-10-01            <NA>               <NA>            <NA>
# 2022-10-31            <NA>               <NA>            <NA>
# 2022-11-30            <NA>               <NA>            <NA>
# 2022-12-31            <NA>               <NA>            <NA>
# 2023-01-01            <NA>               <NA>            <NA>
# 2023-01-28            <NA>               <NA>            <NA>
# 2023-01-29            <NA>               <NA>            <NA>
# 2023-01-31            <NA>               <NA>            <NA>
# 2023-02-25            <NA>               <NA>            <NA>
# 2023-02-26            <NA>               <NA>            <NA>
# 2023-02-28            <NA>               <NA>            <NA>
# 2023-03-02            <NA>               <NA>            <NA>
# 2023-03-04            <NA>               <NA>            <NA>
# 2023-03-25            <NA>               <NA>            <NA>
# 2023-03-31            <NA>               <NA>            <NA>
# 2023-04-01            <NA>               <NA>            <NA>
# 2023-04-02            <NA>               <NA>            <NA>
# 2023-04-03            <NA>               <NA>            <NA>
# 2023-04-28            <NA>               <NA>            <NA>
# 2023-04-30            <NA>               <NA>            <NA>
# 2023-05-31            <NA>               <NA>            <NA>
# 2023-06-25            <NA>               <NA>            <NA>
# 2023-06-30            <NA>               <NA>            <NA>
# 2023-07-02            <NA>               <NA>            <NA>
# 2023-07-29            <NA>               <NA>            <NA>
# 2023-07-31            <NA>               <NA>            <NA>
# 2023-08-01            <NA>               <NA>            <NA>
# 2023-08-31            <NA>               <NA>            <NA>
# 2023-09-30            <NA>               <NA>            <NA>
# 2023-10-31            <NA>               <NA>            <NA>
# 2023-11-30            <NA>               <NA>            <NA>
# 2023-12-30            <NA>               <NA>            <NA>
# 2023-12-31       57.964602          65.346535       23.451327
# 2024-01-31            <NA>               <NA>            <NA>
# 2024-02-29            <NA>               <NA>            <NA>
# 2024-03-30            <NA>               <NA>            <NA>
# 2024-03-31            <NA>               <NA>            <NA>
# 2024-04-01            <NA>               <NA>            <NA>
# 2024-04-30            <NA>               <NA>            <NA>
# 2024-05-31            <NA>               <NA>            <NA>
# 2024-06-30            <NA>               <NA>            <NA>
#
#                                          ...   XANOb.ST                     \
#            Product Responsibility Score  ...  ESG Score ESG Combined Score
# Date                                     ...
# 2008-09-30                         <NA>  ...       <NA>               <NA>
# 2019-12-31                         <NA>  ...       <NA>               <NA>
# 2020-11-30                         <NA>  ...       <NA>               <NA>
# 2020-12-31                         <NA>  ...       <NA>               <NA>
# 2021-03-31                         <NA>  ...       <NA>               <NA>
# 2021-12-31                         <NA>  ...       <NA>               <NA>
# 2022-01-29                         <NA>  ...       <NA>               <NA>
# 2022-01-31                         <NA>  ...       <NA>               <NA>
# 2022-03-31                         <NA>  ...       <NA>               <NA>
# 2022-05-31                         <NA>  ...       <NA>               <NA>
# 2022-06-30                         <NA>  ...       <NA>               <NA>
# 2022-08-31                         <NA>  ...       <NA>               <NA>
# 2022-09-03                         <NA>  ...       <NA>               <NA>
# 2022-09-30                         <NA>  ...       <NA>               <NA>
# 2022-10-01                         <NA>  ...       <NA>               <NA>
# 2022-10-31                         <NA>  ...       <NA>               <NA>
# 2022-11-30                         <NA>  ...       <NA>               <NA>
# 2022-12-31                         <NA>  ...       <NA>               <NA>
# 2023-01-01                         <NA>  ...       <NA>               <NA>
# 2023-01-28                         <NA>  ...       <NA>               <NA>
# 2023-01-29                         <NA>  ...       <NA>               <NA>
# 2023-01-31                         <NA>  ...       <NA>               <NA>
# 2023-02-25                         <NA>  ...       <NA>               <NA>
# 2023-02-26                         <NA>  ...       <NA>               <NA>
# 2023-02-28                         <NA>  ...       <NA>               <NA>
# 2023-03-02                         <NA>  ...       <NA>               <NA>
# 2023-03-04                         <NA>  ...       <NA>               <NA>
# 2023-03-25                         <NA>  ...       <NA>               <NA>
# 2023-03-31                         <NA>  ...       <NA>               <NA>
# 2023-04-01                         <NA>  ...       <NA>               <NA>
# 2023-04-02                         <NA>  ...       <NA>               <NA>
# 2023-04-03                         <NA>  ...       <NA>               <NA>
# 2023-04-28                         <NA>  ...       <NA>               <NA>
# 2023-04-30                         <NA>  ...       <NA>               <NA>
# 2023-05-31                         <NA>  ...       <NA>               <NA>
# 2023-06-25                         <NA>  ...       <NA>               <NA>
# 2023-06-30                         <NA>  ...       <NA>               <NA>
# 2023-07-02                         <NA>  ...       <NA>               <NA>
# 2023-07-29                         <NA>  ...       <NA>               <NA>
# 2023-07-31                         <NA>  ...       <NA>               <NA>
# 2023-08-01                         <NA>  ...       <NA>               <NA>
# 2023-08-31                         <NA>  ...       <NA>               <NA>
# 2023-09-30                         <NA>  ...       <NA>               <NA>
# 2023-10-31                         <NA>  ...       <NA>               <NA>
# 2023-11-30                         <NA>  ...       <NA>               <NA>
# 2023-12-30                         <NA>  ...       <NA>               <NA>
# 2023-12-31                    39.380531  ...  29.941339          29.941339
# 2024-01-31                         <NA>  ...       <NA>               <NA>
# 2024-02-29                         <NA>  ...       <NA>               <NA>
# 2024-03-30                         <NA>  ...       <NA>               <NA>
# 2024-03-31                         <NA>  ...       <NA>               <NA>
# 2024-04-01                         <NA>  ...       <NA>               <NA>
# 2024-04-30                         <NA>  ...       <NA>               <NA>
# 2024-05-31                         <NA>  ...       <NA>               <NA>
# 2024-06-30                         <NA>  ...       <NA>               <NA>
#
#                                                                               \
#            Resource Use Score Emissions Score Environmental Innovation Score
# Date
# 2008-09-30               <NA>            <NA>                           <NA>
# 2019-12-31               <NA>            <NA>                           <NA>
# 2020-11-30               <NA>            <NA>                           <NA>
# 2020-12-31               <NA>            <NA>                           <NA>
# 2021-03-31               <NA>            <NA>                           <NA>
# 2021-12-31               <NA>            <NA>                           <NA>
# 2022-01-29               <NA>            <NA>                           <NA>
# 2022-01-31               <NA>            <NA>                           <NA>
# 2022-03-31               <NA>            <NA>                           <NA>
# 2022-05-31               <NA>            <NA>                           <NA>
# 2022-06-30               <NA>            <NA>                           <NA>
# 2022-08-31               <NA>            <NA>                           <NA>
# 2022-09-03               <NA>            <NA>                           <NA>
# 2022-09-30               <NA>            <NA>                           <NA>
# 2022-10-01               <NA>            <NA>                           <NA>
# 2022-10-31               <NA>            <NA>                           <NA>
# 2022-11-30               <NA>            <NA>                           <NA>
# 2022-12-31               <NA>            <NA>                           <NA>
# 2023-01-01               <NA>            <NA>                           <NA>
# 2023-01-28               <NA>            <NA>                           <NA>
# 2023-01-29               <NA>            <NA>                           <NA>
# 2023-01-31               <NA>            <NA>                           <NA>
# 2023-02-25               <NA>            <NA>                           <NA>
# 2023-02-26               <NA>            <NA>                           <NA>
# 2023-02-28               <NA>            <NA>                           <NA>
# 2023-03-02               <NA>            <NA>                           <NA>
# 2023-03-04               <NA>            <NA>                           <NA>
# 2023-03-25               <NA>            <NA>                           <NA>
# 2023-03-31               <NA>            <NA>                           <NA>
# 2023-04-01               <NA>            <NA>                           <NA>
# 2023-04-02               <NA>            <NA>                           <NA>
# 2023-04-03               <NA>            <NA>                           <NA>
# 2023-04-28               <NA>            <NA>                           <NA>
# 2023-04-30               <NA>            <NA>                           <NA>
# 2023-05-31               <NA>            <NA>                           <NA>
# 2023-06-25               <NA>            <NA>                           <NA>
# 2023-06-30               <NA>            <NA>                           <NA>
# 2023-07-02               <NA>            <NA>                           <NA>
# 2023-07-29               <NA>            <NA>                           <NA>
# 2023-07-31               <NA>            <NA>                           <NA>
# 2023-08-01               <NA>            <NA>                           <NA>
# 2023-08-31               <NA>            <NA>                           <NA>
# 2023-09-30               <NA>            <NA>                           <NA>
# 2023-10-31               <NA>            <NA>                           <NA>
# 2023-11-30               <NA>            <NA>                           <NA>
# 2023-12-30               <NA>            <NA>                           <NA>
# 2023-12-31          11.064892       22.636816                      68.190855
# 2024-01-31               <NA>            <NA>                           <NA>
# 2024-02-29               <NA>            <NA>                           <NA>
# 2024-03-30               <NA>            <NA>                           <NA>
# 2024-03-31               <NA>            <NA>                           <NA>
# 2024-04-01               <NA>            <NA>                           <NA>
# 2024-04-30               <NA>            <NA>                           <NA>
# 2024-05-31               <NA>            <NA>                           <NA>
# 2024-06-30               <NA>            <NA>                           <NA>
#
#                                                                \
#            Workforce Score Human Rights Score Community Score
# Date
# 2008-09-30            <NA>               <NA>            <NA>
# 2019-12-31            <NA>               <NA>            <NA>
# 2020-11-30            <NA>               <NA>            <NA>
# 2020-12-31            <NA>               <NA>            <NA>
# 2021-03-31            <NA>               <NA>            <NA>
# 2021-12-31            <NA>               <NA>            <NA>
# 2022-01-29            <NA>               <NA>            <NA>
# 2022-01-31            <NA>               <NA>            <NA>
# 2022-03-31            <NA>               <NA>            <NA>
# 2022-05-31            <NA>               <NA>            <NA>
# 2022-06-30            <NA>               <NA>            <NA>
# 2022-08-31            <NA>               <NA>            <NA>
# 2022-09-03            <NA>               <NA>            <NA>
# 2022-09-30            <NA>               <NA>            <NA>
# 2022-10-01            <NA>               <NA>            <NA>
# 2022-10-31            <NA>               <NA>            <NA>
# 2022-11-30            <NA>               <NA>            <NA>
# 2022-12-31            <NA>               <NA>            <NA>
# 2023-01-01            <NA>               <NA>            <NA>
# 2023-01-28            <NA>               <NA>            <NA>
# 2023-01-29            <NA>               <NA>            <NA>
# 2023-01-31            <NA>               <NA>            <NA>
# 2023-02-25            <NA>               <NA>            <NA>
# 2023-02-26            <NA>               <NA>            <NA>
# 2023-02-28            <NA>               <NA>            <NA>
# 2023-03-02            <NA>               <NA>            <NA>
# 2023-03-04            <NA>               <NA>            <NA>
# 2023-03-25            <NA>               <NA>            <NA>
# 2023-03-31            <NA>               <NA>            <NA>
# 2023-04-01            <NA>               <NA>            <NA>
# 2023-04-02            <NA>               <NA>            <NA>
# 2023-04-03            <NA>               <NA>            <NA>
# 2023-04-28            <NA>               <NA>            <NA>
# 2023-04-30            <NA>               <NA>            <NA>
# 2023-05-31            <NA>               <NA>            <NA>
# 2023-06-25            <NA>               <NA>            <NA>
# 2023-06-30            <NA>               <NA>            <NA>
# 2023-07-02            <NA>               <NA>            <NA>
# 2023-07-29            <NA>               <NA>            <NA>
# 2023-07-31            <NA>               <NA>            <NA>
# 2023-08-01            <NA>               <NA>            <NA>
# 2023-08-31            <NA>               <NA>            <NA>
# 2023-09-30            <NA>               <NA>            <NA>
# 2023-10-31            <NA>               <NA>            <NA>
# 2023-11-30            <NA>               <NA>            <NA>
# 2023-12-30            <NA>               <NA>            <NA>
# 2023-12-31       11.586314           2.607914       19.517885
# 2024-01-31            <NA>               <NA>            <NA>
# 2024-02-29            <NA>               <NA>            <NA>
# 2024-03-30            <NA>               <NA>            <NA>
# 2024-03-31            <NA>               <NA>            <NA>
# 2024-04-01            <NA>               <NA>            <NA>
# 2024-04-30            <NA>               <NA>            <NA>
# 2024-05-31            <NA>               <NA>            <NA>
# 2024-06-30            <NA>               <NA>            <NA>
#
#
#            Product Responsibility Score ESG Controversies Score
# Date
# 2008-09-30                         <NA>                    <NA>
# 2019-12-31                         <NA>                    <NA>
# 2020-11-30                         <NA>                    <NA>
# 2020-12-31                         <NA>                    <NA>
# 2021-03-31                         <NA>                    <NA>
# 2021-12-31                         <NA>                    <NA>
# 2022-01-29                         <NA>                    <NA>
# 2022-01-31                         <NA>                    <NA>
# 2022-03-31                         <NA>                    <NA>
# 2022-05-31                         <NA>                    <NA>
# 2022-06-30                         <NA>                    <NA>
# 2022-08-31                         <NA>                    <NA>
# 2022-09-03                         <NA>                    <NA>
# 2022-09-30                         <NA>                    <NA>
# 2022-10-01                         <NA>                    <NA>
# 2022-10-31                         <NA>                    <NA>
# 2022-11-30                         <NA>                    <NA>
# 2022-12-31                         <NA>                    <NA>
# 2023-01-01                         <NA>                    <NA>
# 2023-01-28                         <NA>                    <NA>
# 2023-01-29                         <NA>                    <NA>
# 2023-01-31                         <NA>                    <NA>
# 2023-02-25                         <NA>                    <NA>
# 2023-02-26                         <NA>                    <NA>
# 2023-02-28                         <NA>                    <NA>
# 2023-03-02                         <NA>                    <NA>
# 2023-03-04                         <NA>                    <NA>
# 2023-03-25                         <NA>                    <NA>
# 2023-03-31                         <NA>                    <NA>
# 2023-04-01                         <NA>                    <NA>
# 2023-04-02                         <NA>                    <NA>
# 2023-04-03                         <NA>                    <NA>
# 2023-04-28                         <NA>                    <NA>
# 2023-04-30                         <NA>                    <NA>
# 2023-05-31                         <NA>                    <NA>
# 2023-06-25                         <NA>                    <NA>
# 2023-06-30                         <NA>                    <NA>
# 2023-07-02                         <NA>                    <NA>
# 2023-07-29                         <NA>                    <NA>
# 2023-07-31                         <NA>                    <NA>
# 2023-08-01                         <NA>                    <NA>
# 2023-08-31                         <NA>                    <NA>
# 2023-09-30                         <NA>                    <NA>
# 2023-10-31                         <NA>                    <NA>
# 2023-11-30                         <NA>                    <NA>
# 2023-12-30                         <NA>                    <NA>
# 2023-12-31                    32.012678                     100
# 2024-01-31                         <NA>                    <NA>
# 2024-02-29                         <NA>                    <NA>
# 2024-03-30                         <NA>                    <NA>
# 2024-03-31                         <NA>                    <NA>
# 2024-04-01                         <NA>                    <NA>
# 2024-04-30                         <NA>                    <NA>
# 2024-05-31                         <NA>                    <NA>
# 2024-06-30                         <NA>                    <NA>
#
# [55 rows x 11000 columns]

# %%
concat_inst_esg = pd.DataFrame()
for instrument in esg_scores:
    ins_df = esg_Scores[instrument]
    ins_df["Intrument"] = instrument

# %%
spx = rd.get_data('0#.SPX',['TR.TRBCEconomicSector','TR.TRESGScore(Period=FY0)', 
                                 'TR.TRESGCScore(Period=FY0)','TR.TRESGCControversiesScore(Period=FY0)', 'TR.HeadquartersRegion'])

spx
# Out:
#     Instrument TRBC Economic Sector Name  ESG Score  ESG Combined Score  \
# 0      POOL.OQ        Consumer Cyclicals  50.640994           50.640994
# 1      CHRW.OQ               Industrials  41.165895           41.165895
# 2        AJG.N                Financials   50.61887            50.61887
# 3        CNP.N                 Utilities  46.144726           32.447363
# 4       AMCR.N           Basic Materials  73.264793           68.299063
# ..         ...                       ...        ...                 ...
# 498      PSX.N                    Energy  68.956784           44.663577
# 499     SCHW.N                Financials   53.71592           48.199424
# 500    SNPS.OQ                Technology  60.671843           60.671843
# 501        J.N               Industrials  78.012206           62.119311
# 502      AVY.N           Basic Materials  74.137588           74.137588
#
#      ESG Controversies Score Region of Headquarters
# 0                      100.0               Americas
# 1                      100.0               Americas
# 2                      100.0               Americas
# 3                      18.75               Americas
# 4                  63.333333                 Europe
# ..                       ...                    ...
# 498                 20.37037               Americas
# 499                42.682927               Americas
# 500                81.578947               Americas
# 501                46.226415               Americas
# 502                    100.0               Americas
#
# [503 rows x 6 columns]
